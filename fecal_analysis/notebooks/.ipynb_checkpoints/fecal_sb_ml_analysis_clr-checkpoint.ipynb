# %% [markdown]
# # Nobel Twin Cirrhosis Fecal Machine Learning Analysis
# This workflow uses machine learning and features from Songbird to try and classify individuals as positive or negative for advanced fibrosis. I will create 3 different feature sets: songbird top 50, songbird bot 50 and songbird top 25+bot25. With each of these feature sets I will test the Random Forest classifer model and a logistic regression model and use the precision recall curve to test how well the models perform. I will be using the `fecal-ft-matched-clr.qza` feature table.
#
# **Author: Tobin Groth (tgroth@ucsd.edu)**

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import qiime2
from sklearn import preprocessing
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_validate
from sklearn import metrics
from sklearn.utils import shuffle
import numpy as np
import pylab as pl
import qiime2
import os


os.chdir('/Users/tgroth/Google Drive/knight_twin_NAFLD/fecal_analysis')

# %%
#loading in fecal metadata
meta = pd.read_csv('../metadata-matched.tsv',sep='\t',index_col=0)
meta.head(3)
# Out:
#            ATTRIBUTE_AgeInYears ATTRIBUTE_BarcodeSequence  \
# sampleid
# TW-CO-002                    54              TCATGGCCTCCG
# TW-BT-001                    49              CACACAAAGTCA
# TW-CA-002                    61              TCCGGCGGGCAA
#
#           ATTRIBUTE_BiologicalSex ATTRIBUTE_ChromatographyAndPhase  \
# sampleid
# TW-CO-002                    male                   not applicable
# TW-BT-001                  female                   not applicable
# TW-CA-002                    male                   not applicable
#
#           ATTRIBUTE_ComorbidityListDOIDIndex         ATTRIBUTE_Country  \
# sampleid
# TW-CO-002                     not applicable  United States of America
# TW-BT-001                     not applicable  United States of America
# TW-CA-002                     not applicable  United States of America
#
#           ATTRIBUTE_DOIDCommonName ATTRIBUTE_DOIDOntologyIndex  \
# sampleid
# TW-CO-002           not applicable              not applicable
# TW-BT-001           not applicable              not applicable
# TW-CA-002           not applicable              not applicable
#
#            ATTRIBUTE_DepthorAltitudeMeters ATTRIBUTE_Description  ...  \
# sampleid                                                          ...
# TW-CO-002                              200    loomba_nobel_liver  ...
# TW-BT-001                              200    loomba_nobel_liver  ...
# TW-CA-002                              200    loomba_nobel_liver  ...
#
#           ATTRIBUTE_waist_circumference_cm ATTRIBUTE_water_lot ATTRIBUTE_wbc  \
# sampleid
# TW-CO-002                               98            RNBF9925             8
# TW-BT-001                               92            RNBF9925           8.5
# TW-CA-002                              115            RNBF9925           6.2
#
#           ATTRIBUTE_weight ATTRIBUTE_weight_units  \
# sampleid
# TW-CO-002             80.6                     kg
# TW-BT-001             80.8                     kg
# TW-CA-002             99.7                     kg
#
#                   ATTRIBUTE_well_description ATTRIBUTE_well_id  \
# sampleid
# TW-CO-002   Loomba_Twin_Plate_2_TW.CO.002_E2                E2
# TW-BT-001  Loomba_Twin_Plate_2_TW.BT.001_E10               E10
# TW-CA-002  Loomba_Twin_Plate_2_TW.CA.002_B10               B10
#
#           ATTRIBUTE_zygocity ATTRIBUTE_zygoticity  \
# sampleid
# TW-CO-002                  2                  2.0
# TW-BT-001                  1                  1.0
# TW-CA-002                  1                  1.0
#
#                                 filename
# sampleid
# TW-CO-002   TW-CO-002_RC4_01_35874.mzXML
# TW-BT-001  TW-BT-001_RH12_01_35942.mzXML
# TW-CA-002   TW-CA-002_RH6_01_35936.mzXML
#
# [3 rows x 168 columns]

# %%
meta.ATTRIBUTE_groups.value_counts()
# Out:
# G1P    48
# G1R    37
# G3R    30
# G3P    22
# G2P    16
# G2R    14
# Name: ATTRIBUTE_groups, dtype: int64

# %%
#loading in the fecal clr table
fecal_table = qiime2.Artifact.load('feature_tables/fecal-ft-matched-clr.qza')
fecal_tablepd = fecal_table.view(pd.DataFrame)
fecal_tablepd.head(3)
# Out:
#            00130daba4ed7c3091cebe843923b656  0035e736dc271e0ffa69ce089124dd3a  \
# TW-CO-002                         -1.216757                         -1.216757
# TW-BT-001                         -1.400544                         -1.400544
# TW-CA-002                         -0.911016                         -0.911016
#
#            00b990effdb1e3547be73fc221c47da9  00bf884546e085e1d7341e1b4d5b4c7f  \
# TW-CO-002                         -1.216757                         -1.216757
# TW-BT-001                         -1.400544                         -1.400544
# TW-CA-002                         -0.911016                         -0.911016
#
#            00d4834e98bff02228bc6022ad218b38  013d75d35d7937c40332f8492e0ac45d  \
# TW-CO-002                          6.153988                         -1.216757
# TW-BT-001                          6.991458                         -1.400544
# TW-CA-002                          6.331897                         -0.911016
#
#            0178e96df0dc4d287475a41115a80ff5  018aa6775f054d00a3af02b1f142bd7f  \
# TW-CO-002                         -1.216757                         -1.216757
# TW-BT-001                         -1.400544                         -1.400544
# TW-CA-002                         -0.911016                         -0.911016
#
#            019f30f6e7668fa412b214ddaa35c150  0285b154e241302fc53e9f2aa1cb74f2  \
# TW-CO-002                         -1.216757                         -1.216757
# TW-BT-001                          7.820646                         -1.400544
# TW-CA-002                         -0.911016                         -0.911016
#
#            ...  fbda8d94f713b714f135c441853dc12d  \
# TW-CO-002  ...                         -1.216757
# TW-BT-001  ...                         -1.400544
# TW-CA-002  ...                         -0.911016
#
#            fc6931386367002a15c8854e10f1411f  fc69c5f3c21f8a3c984509dfa751197a  \
# TW-CO-002                         -1.216757                         -1.216757
# TW-BT-001                         -1.400544                         -1.400544
# TW-CA-002                         -0.911016                         -0.911016
#
#            fc81ed8373e77dc1051c32775cbe8156  fc9687d47db7ef11369d303f56b588c2  \
# TW-CO-002                          7.019762                         -1.216757
# TW-BT-001                         -1.400544                         -1.400544
# TW-CA-002                          6.343465                         -0.911016
#
#            fc9ed967c73557234a3a59e5f3921dcb  fd166de6a32d83ea5d14ccf2bb4a04c9  \
# TW-CO-002                         -1.216757                         -1.216757
# TW-BT-001                         -1.400544                         -1.400544
# TW-CA-002                         -0.911016                         -0.911016
#
#            ff56dd5a9e0f7171e04d3f576d03fd87  ff6c014126b685e755c395c10017f17d  \
# TW-CO-002                         -1.216757                         -1.216757
# TW-BT-001                         -1.400544                         -1.400544
# TW-CA-002                         -0.911016                         -0.911016
#
#            fff3d0fb371c075ad5340cf5738683da
# TW-CO-002                         -1.216757
# TW-BT-001                         -1.400544
# TW-CA-002                          8.861582
#
# [3 rows x 985 columns]

# %% [markdown]
# ## Creating The Different Feature sets

# %%
#loading in Songbird differentials
sb_diff = pd.read_csv('songbird_analysis/fecal-sb-differentials.tsv',sep='\t')
#sorting table by association with AF
sb_diff_AF = sb_diff.sort_values(by=['ATTRIBUTE_adv_fibrosis[T.1]'],ascending=False)
sb_diff_AF.head(3)
# Out:
#                             featureid  Intercept  ATTRIBUTE_adv_fibrosis[T.1]  \
# 434  f16fb9a4556296869e4f5e582a914dd2  -1.148390                     2.699331
# 327  b88289a6da54ad61fca21f4ecab92fd9   0.035932                     2.607807
# 136  4c25b8be76070246953849e3931a78c6  -1.103523                     2.511860
#
#      ATTRIBUTE_adv_fibrosis[T.Missing: Not collected]
# 434                                          0.004227
# 327                                          0.004227
# 136                                          0.004227

# %%
sb_top50_id = list(sb_diff_AF.iloc[0:50].featureid)
sb_bot50_id = list(sb_diff_AF.iloc[-51:-1].featureid)
sb_tb25_id = list(sb_diff_AF.iloc[0:25].featureid)+list(sb_diff_AF.iloc[-26:-1].featureid)

# %%
sb_top50_table = fecal_tablepd.loc[:,sb_top50_id]
sb_bot50_table = fecal_tablepd.loc[:,sb_bot50_id]
sb_tb25_table = fecal_tablepd.loc[:,sb_tb25_id]
print(sb_top50_table.shape)
print(sb_bot50_table.shape)
print(sb_tb25_table.shape)
# Out:
# (167, 50)
# (167, 50)
# (167, 50)

# %% [markdown]
# ## 1. Songbird top 50 Features
# I will compare the performace of the logistic regression and the random forest on the sb top 50 feature set

# %% [markdown]
# ### 1a. CV/Train the models on G1P+G3P individuals

# %%
# get all the samples that are either in group G1P G3P
train_samples = ([idx for idx in meta[meta.ATTRIBUTE_groups=='G1P'].index]
            + [idx for idx in meta[meta.ATTRIBUTE_groups=='G3P'].index])
train_table = meta.loc[train_samples][['ATTRIBUTE_groups','ATTRIBUTE_adv_fibrosis']]
train_table.rename(columns={'ATTRIBUTE_groups':'groups','ATTRIBUTE_adv_fibrosis':'adv_fibrosis'},inplace=True)
print(train_table.groups.value_counts())
print(train_table.adv_fibrosis.value_counts())
# Out:
# G1P    48
# G3P    22
# Name: groups, dtype: int64
# 0                         44
# 1                         22
# Missing: Not collected     4
# Name: adv_fibrosis, dtype: int64

# %%
#preparing training data for SB top 50
x_train_top = sb_top50_table.loc[train_table.index]
#label encoder
y_train_top = []
for idx in train_table.index:
    if train_table.loc[idx,'adv_fibrosis'] == '1':
        y_train_top.append(1)
    #even values that are 'missing' are still 0 for adv fibrosis
    else:
        y_train_top.append(0)
y_train_top = np.array(y_train_top)
print(x_train_top.shape)
print(len(y_train_top))
# Out:
# (70, 50)
# 70

# %%
#creating method for cross validating model by plotting ROC
#cf==0 for log reg, cf==1 for RF
def cross_val_roc(cf, x_train, y_train, title, split=5,):
    from sklearn.model_selection import StratifiedShuffleSplit, StratifiedKFold
    from sklearn.linear_model import LogisticRegression
    from sklearn.metrics import roc_curve, auc
    from scipy import interp

    fig = plt.figure()
    ax = plt.subplot(111)
    
    
    # Run classifier with crossvalidation and plot ROC curves
    cv =StratifiedShuffleSplit(n_splits=split, test_size=0.3, random_state=9)
    if cf == 0:
        cf_test1 = LogisticRegression(random_state=0,max_iter=500)
    else:
        cf_test1 = RandomForestClassifier(n_estimators=500, n_jobs=4, random_state=0)

    mean_tpr = 0.0
    mean_fpr = np.linspace(0, 1, 100)
    all_tpr = []
    for train, test in cv.split(x_train,y_train):
        probas_ = cf_test1.fit(x_train.iloc[train], y_train[train]).predict_proba(x_train.iloc[test])
        # Compute ROC curve and area the curve
        fpr, tpr, thresholds = roc_curve(y_train[test], probas_[:,1])
        mean_tpr += np.interp(mean_fpr, fpr, tpr)
        mean_tpr[0] = 0.0
        roc_auc = auc(fpr, tpr)
        pl.plot(fpr, tpr, lw=1, label='ROC (area = %0.2f)' %  roc_auc)

    pl.plot([0, 1], [0, 1], '--', color=(0.6,0.6,0.6), label='Luck')
    mean_tpr /= cv.get_n_splits()
    mean_tpr[-1] = 1.0
    mean_auc = auc(mean_fpr, mean_tpr)
    pl.plot(mean_fpr, mean_tpr, 'k--',
            label='Mean ROC (area = %0.2f)' % mean_auc, lw=2)

    pl.xlim([-0.05,1.05])
    pl.ylim([-0.05,1.05])
    pl.xlabel('False Positive Rate')
    pl.ylabel('True Positive Rate')
    pl.title(title)
    ax.legend(bbox_to_anchor=(1, 1))
    return pl

# %%
#creating method for cross validating model by plotting Precision-Recall curve
#cf==0 for log reg, cf==1 for RF
def cross_val_pr(cf, x_train, y_train, title, split=5,):
    from sklearn.model_selection import StratifiedShuffleSplit, StratifiedKFold
    from sklearn.metrics import precision_recall_curve
    from sklearn.ensemble import RandomForestClassifier
    from sklearn.linear_model import LogisticRegression
    from sklearn.metrics import roc_curve, auc
    from scipy import interp

    
    fig = plt.figure()
    ax = plt.subplot(111)
    
    # Run classifier with crossvalidation and plot precision-recall curves
    cv =StratifiedShuffleSplit(n_splits=split, test_size=0.4, random_state=9)
    if cf == 0:
        cf_test1 = LogisticRegression(random_state=0,max_iter=500)
    else:
        cf_test1 = RandomForestClassifier(n_estimators=500, n_jobs=4, random_state=0)

    mean_precision = 0.0
    mean_recall = np.linspace(1, 0, 100)
    all_precision = []

    for train, test in cv.split(x_train,y_train):
        probas_ = cf_test1.fit(x_train.iloc[train], y_train[train]).predict_proba(x_train.iloc[test])
        # Compute precision-recall curve and area the curve
        precision, recall, thresholds = precision_recall_curve(y_train[test], probas_[:,1])
        #fpr, tpr, thresholds = roc_curve(y_train[test], probas_[:,1])
        rev_recall = recall[::-1]
        rev_precision = precision[::-1]
        mp = np.interp(mean_recall, rev_recall, rev_precision)
        #print(mp)
        mean_precision += mp
        #mean_precision[0] = 1.0
        pr_auc = auc(rev_recall, rev_precision)
        plt.plot(recall, precision, lw=1, label='Precision-Recall (area = %0.2f)' %  pr_auc)

    #plt.plot([0, 1], [1, 0], '--', color=(0.6,0.6,0.6), label='Luck')

    mean_precision /= cv.get_n_splits()
    #mean_precision[-1] = 1.0
    mean_auc = auc(mean_recall, mean_precision)
    #print(mean_recall)
    #print(mean_precision)
    plt.plot(mean_recall, mean_precision, 'k--',
            label='Mean Precision-Recall (area = %0.2f)' % mean_auc, lw=2)

    plt.xlim([-0.05,1.05])
    plt.ylim([-0.05,1.05])
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.title(title)
    ax.legend(bbox_to_anchor=(1, 1))
    #plt.legend(loc="lower right")
    return plt

# %%
#plotting CV for Log reg
fig_lr = cross_val_pr(0,x_train_top,y_train_top,'PR Curve Cross Validation')
fig_lr.savefig('ml_analysis/sb_analysis/clr_figures/lr_sbTOP50_cv_pr.pdf',bbox_inches='tight')

fig_lr = cross_val_roc(0,x_train_top,y_train_top,'ROC Curve Cross Validation')
fig_lr.savefig('ml_analysis/sb_analysis/clr_figures/lr_sbTOP50_cv_roc.pdf',bbox_inches='tight')

# %%
#plotting CV for RF
fig_rf = cross_val_pr(1,x_train_top,y_train_top,'PR Curve Cross Validation')
fig_rf.savefig('ml_analysis/sb_analysis/clr_figures/rf_sbTOP50_cv_pr.pdf',bbox_inches='tight')

fig_rf = cross_val_roc(1,x_train_top,y_train_top,'ROC Curve Cross Validation')
fig_rf.savefig('ml_analysis/sb_analysis/clr_figures/rf_sbTOP50_cv_roc.pdf',bbox_inches='tight')

# %%
#training Log Reg on training data
top_lr = LogisticRegression(random_state=0,max_iter=200)
top_lr.fit(x_train_top, y_train_top)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=200,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=0, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
#training RF on training data
top_rf = RandomForestClassifier(500, oob_score=True, random_state=0)
top_rf.fit(x_train_top, y_train_top)
top_rf.oob_score_
# Out:
# 0.6428571428571429

# %% [markdown]
# ### 1b. Testing the models on G3P Samples

# %%
# get all the samples that are G3R
test_samples = [idx for idx in meta[meta.ATTRIBUTE_groups=='G3R'].index if idx in fecal_tablepd.index]
test_table = meta.loc[test_samples][['ATTRIBUTE_groups','ATTRIBUTE_adv_fibrosis']]
test_table.rename(columns={'ATTRIBUTE_groups':'groups','ATTRIBUTE_adv_fibrosis':'adv_fibrosis'},inplace=True)
#have to drop Missing: Not collected values
test_table = test_table[test_table.adv_fibrosis != 'Missing: Not collected']
print(test_table.adv_fibrosis.value_counts())
# Out:
# 0    21
# 1     7
# Name: adv_fibrosis, dtype: int64

# %%
# Preparing the test data for SB
x_test_top = sb_top50_table.loc[test_table.index]
y_test_top = []
for idx in test_table.index:
    if test_table.loc[idx,'adv_fibrosis'] == '1':
        y_test_top.append(1)
    elif test_table.loc[idx,'adv_fibrosis'] == '0':
        y_test_top.append(0)
y_test_top = np.array(y_test_top)
print(len(x_test_top))
print(len(y_test_top))
# Out:
# 28
# 28

# %%
#plotting Precision Recall curve 
#(code used from calour.plot_roc http://biocore.github.io/calour/generated/calour.training.plot_roc.html)
def plot_result_pr(result,title,cv=True):
    from sklearn import metrics
    from matplotlib import pyplot as plt
    from scipy import interp
    import itertools
    
    cmap = plt.cm.Dark2
    fig, ax = plt.subplots()
    ax.set_aspect('equal')
    #ax.plot([0, 1], [0, 1], linestyle='-', lw=1, color='black', label='Luck', alpha=.5)

    classes = np.unique(result['Y_TRUE'].values)
    classes.sort()

    col = dict(zip(classes, itertools.cycle(cmap.colors)))

    mean_recall = np.linspace(1, 0, 100)
    for cls in classes:
        precisions = []
        aucs = []
        if cv is True:
            for grp, df in result.groupby('CV'):
                y_true = df['Y_TRUE'].values == cls
                precision, recall, thresholds = metrics.precision_recall_curve(y_true.astype(int), result[cls])
                rev_recall = recall[::-1]
                rev_precision = precision[::-1]
                mean_precision = np.interp(mean_recall, rev_recall, rev_precision)
                precisions.append(mean_precision)
                precisions[-1][0] = 0.0
                pr_auc = metrics.auc(mean_recall, mean_precision)
                aucs.append(pr_auc)

            mean_precision = np.mean(precisions, axis=0)
            #mean_tpr[-1] = 1.0
            mean_auc = np.mean(aucs)
            std_auc = np.std(aucs)
            ax.plot(mean_recall, mean_precision, color=col[cls],
                    label='{0} ({1:.2f} $\\pm$ {2:.2f})'.format(cls, mean_auc, std_auc),
                    lw=2, alpha=.8)

            std_precision = np.std(precisions, axis=0)
            precisions_upper = np.minimum(mean_precision + std_precision, 1)
            precisions_lower = np.maximum(mean_precision - std_precision, 0)
            ax.fill_between(mean_recall, precisions_lower, precisions_upper, color=col[cls], alpha=.5)
        else:
            y_true = result['Y_TRUE'].values == cls
            precision, recall, thresholds = metrics.precision_recall_curve(y_true.astype(int), result[cls])
            pr_auc = auc(recall, precision)
            # prepend zero because, if not, the curve may start in the middle of the plot.
            ax.plot(np.insert(recall, 0, 0), np.insert(precision, 0, 0), label='{0} ({1:.2f})'.format(cls, pr_auc), lw=2)

    ax.set_xlim(-0.05, 1.05)
    ax.set_ylim(-0.05, 1.05)
    ax.set_xlabel('Recall')
    ax.set_ylabel('Precision')
    ax.set_title(title)
    ax.legend(loc="lower right")

    #return ax, mean_auc if cv else pr_auc
    return plt

# %%
#plotting ROC curve 
#(code used from calour.plot_roc http://biocore.github.io/calour/generated/calour.training.plot_roc.html)
def plot_result_roc(result,title,cv=True):    
    from sklearn import metrics
    from matplotlib import pyplot as plt
    from scipy import interp
    import itertools
    
    cmap = plt.cm.Dark2
    fig, ax = plt.subplots()
    ax.set_aspect('equal')
    ax.plot([0, 1], [0, 1], linestyle='-', lw=1, color='black', label='Luck', alpha=.5)

    classes = np.unique(result['Y_TRUE'].values)
    classes.sort()

    col = dict(zip(classes, itertools.cycle(cmap.colors)))

    mean_fpr = np.linspace(0, 1, 100)
    for cls in classes:
        tprs = []
        aucs = []
        if cv is True:
            for grp, df in result.groupby('CV'):
                y_true = df['Y_TRUE'].values == cls
                fpr, tpr, thresholds = metrics.roc_curve(y_true.astype(int), df[cls])
                mean_tpr = np.interp(mean_fpr, fpr, tpr)
                tprs.append(mean_tpr)
                tprs[-1][0] = 0.0
                roc_auc = metrics.auc(mean_fpr, mean_tpr)
                aucs.append(roc_auc)

            mean_tpr = np.mean(tprs, axis=0)
            mean_tpr[-1] = 1.0
            mean_auc = np.mean(aucs)
            std_auc = np.std(aucs)
            ax.plot(mean_fpr, mean_tpr, color=col[cls],
                    label='{0} ({1:.2f} $\\pm$ {2:.2f})'.format(cls, mean_auc, std_auc),
                    lw=2, alpha=.8)

            std_tpr = np.std(tprs, axis=0)
            tprs_upper = np.minimum(mean_tpr + std_tpr, 1)
            tprs_lower = np.maximum(mean_tpr - std_tpr, 0)
            ax.fill_between(mean_fpr, tprs_lower, tprs_upper, color=col[cls], alpha=.5)
        else:
            y_true = result['Y_TRUE'].values == cls
            fpr, tpr, thresholds = roc_curve(y_true.astype(int), result[cls])
            roc_auc = auc(fpr, tpr)
            # prepend zero because, if not, the curve may start in the middle of the plot.
            ax.plot(np.insert(fpr, 0, 0), np.insert(tpr, 0, 0), label='{0} ({1:.2f})'.format(cls, roc_auc), lw=2)

    ax.set_xlim(-0.05, 1.05)
    ax.set_ylim(-0.05, 1.05)
    ax.set_xlabel('False Positive Rate')
    ax.set_ylabel('True Positive Rate')
    ax.set_title(title)
    ax.legend(loc="lower right")

    #return ax, mean_auc if cv else roc_auc
    return plt

# %%
#testing the logistic regression base model
result_top_lr = pd.DataFrame(top_lr.predict_proba(x_test_top))
result_top_lr.columns = top_lr.classes_
result_top_lr['Y_TRUE'] = y_test_top
result_top_lr['CV'] = 0

# %%
#plotting results as Precision Recall curve
fig_lr = plot_result_pr(result_top_lr,'PR Curve Test')
fig_lr.savefig('ml_analysis/sb_analysis/clr_figures/lr_sbTOP50_test_pr.pdf',bbox_inches='tight')

average_precision = metrics.average_precision_score(y_test_top, top_lr.predict(x_test_top))

print('Average precision-recall score: {0:0.2f}'.format(
      average_precision))
# Out:
# Average precision-recall score: 0.24

# %%
#plotting results as ROC
fig_lr = plot_result_roc(result_top_lr,'ROC Curve Test')
fig_lr.savefig('ml_analysis/sb_analysis/clr_figures/lr_sbTOP50_test_roc.pdf',bbox_inches='tight')

acc_score = metrics.accuracy_score(y_test_top, top_lr.predict(x_test_top))

print('Accuracy score: {0:0.2f}'.format(
      acc_score))
# Out:
# Accuracy score: 0.57

# %%
#testing the logistic regression base model
result_top_rf = pd.DataFrame(top_rf.predict_proba(x_test_top))
result_top_rf.columns = top_rf.classes_
result_top_rf['Y_TRUE'] = y_test_top
result_top_rf['CV'] = 0

# %%
#plotting results as Precision Recall curve
fig_rf = plot_result_pr(result_top_rf,'PR Curve Test')
fig_rf.savefig('ml_analysis/sb_analysis/clr_figures/rf_sbTOP50_test_pr.pdf',bbox_inches='tight')

average_precision = metrics.average_precision_score(y_test_top, top_rf.predict(x_test_top))

print('Average precision-recall score: {0:0.2f}'.format(
      average_precision))
# Out:
# Average precision-recall score: 0.29

# %%
#plotting results as ROC
fig_rf = plot_result_roc(result_top_rf,'ROC Curve Test')
fig_rf.savefig('ml_analysis/sb_analysis/clr_figures/rf_sbTOP50_test_roc.pdf',bbox_inches='tight')

acc_score = metrics.accuracy_score(y_test_top, top_rf.predict(x_test_top))

print('Accuracy score: {0:0.2f}'.format(
      acc_score))
# Out:
# Accuracy score: 0.71

# %% [markdown]
# ## 2. Songbird Top25+Bot25

# %% [markdown]
# ### 2a. CV/Train the models on the G1P+G3P individuals

# %%
#preparing training data for SB top 50
x_train_tb = sb_tb25_table.loc[train_table.index]
#label encoder
y_train_tb = []
for idx in train_table.index:
    if train_table.loc[idx,'adv_fibrosis'] == '1':
        y_train_tb.append(1)
    #even values that are 'missing' are still 0 for adv fibrosis
    else:
        y_train_tb.append(0)
y_train_tb = np.array(y_train_tb)
print(x_train_tb.shape)
print(len(y_train_tb))
# Out:
# (70, 50)
# 70

# %%
#plotting Precision-recall for Log Reg
fig_lr = cross_val_pr(0,x_train_tb,y_train_tb,'PR Curve Cross Validation')
fig_lr.savefig('ml_analysis/sb_analysis/clr_figures/lr_sbTB25_cv_pr.pdf',bbox_inches='tight')

#plotting ROC for Log Reg
fig_lr = cross_val_roc(0,x_train_tb,y_train_tb,'ROC Curve Cross Validation')
fig_lr.savefig('ml_analysis/sb_analysis/clr_figures/lr_sbTB25_cv_roc.pdf',bbox_inches='tight')

# %%
#plotting Precision-recall for Log Reg
fig_rf = cross_val_pr(1,x_train_tb,y_train_tb,'PR Curve Cross Validation')
fig_rf.savefig('ml_analysis/sb_analysis/clr_figures/rf_sbTB25_cv_pr.pdf',bbox_inches='tight')

#plotting ROC for Log Reg
fig_rf = cross_val_roc(1,x_train_tb,y_train_tb,'ROC Curve Cross Validation')
fig_rf.savefig('ml_analysis/sb_analysis/clr_figures/rf_sbTB25_cv_roc.pdf',bbox_inches='tight')

# %%
#training Log Reg on training data
tb_lr = LogisticRegression(random_state=0,max_iter=200)
tb_lr.fit(x_train_tb, y_train_tb)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=200,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=0, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
#training RF on training data
tb_rf = RandomForestClassifier(500, oob_score=True, random_state=0)
tb_rf.fit(x_train_tb, y_train_tb)
tb_rf.oob_score_
# Out:
# 0.6428571428571429

# %% [markdown]
# ### 2b. Testing models on G3R Samples

# %%
# Preparing the test data for top 25 bot 25
x_test_tb = sb_tb25_table.loc[test_table.index]
y_test_tb = []
for idx in test_table.index:
    if test_table.loc[idx,'adv_fibrosis'] == '1':
        y_test_tb.append(1)
    elif test_table.loc[idx,'adv_fibrosis'] == '0':
        y_test_tb.append(0)
y_test_tb = np.array(y_test_tb)
print(len(x_test_tb))
print(len(y_test_tb))
# Out:
# 28
# 28

# %%
#testing the logistic regression model
result_tb_lr = pd.DataFrame(tb_lr.predict_proba(x_test_tb))
result_tb_lr.columns = tb_lr.classes_
result_tb_lr['Y_TRUE'] = y_test_tb
result_tb_lr['CV'] = 0

# %%
#plotting results as Precision Recall curve
fig_lr = plot_result_pr(result_tb_lr,'PR Curve Test')
fig_lr.savefig('ml_analysis/sb_analysis/clr_figures/lr_sbTB25_test_pr.pdf',bbox_inches='tight')

average_precision = metrics.average_precision_score(y_test_tb, tb_lr.predict(x_test_tb))

print('Average precision-recall score: {0:0.2f}'.format(
      average_precision))
# Out:
# Average precision-recall score: 0.36

# %%
#plotting results as ROC
fig_lr = plot_result_roc(result_tb_lr,'ROC Curve Test')
fig_lr.savefig('ml_analysis/sb_analysis/clr_figures/lr_sbTB25_test_roc.pdf',bbox_inches='tight')

acc_score = metrics.accuracy_score(y_test_tb, tb_lr.predict(x_test_tb))

print('Accuracy score: {0:0.2f}'.format(
      acc_score))
# Out:
# Accuracy score: 0.75

# %%
#testing the logistic regression base model
result_tb_rf = pd.DataFrame(tb_rf.predict_proba(x_test_tb))
result_tb_rf.columns = tb_rf.classes_
result_tb_rf['Y_TRUE'] = y_test_tb
result_tb_rf['CV'] = 0

# %%
#plotting results as Precision Recall curve
fig_rf = plot_result_pr(result_tb_rf,'PR Curve Test')
fig_rf.savefig('ml_analysis/sb_analysis/clr_figures/rf_sbTB25_test_pr.pdf',bbox_inches='tight')

average_precision = metrics.average_precision_score(y_test_tb, tb_rf.predict(x_test_tb))

print('Average precision-recall score: {0:0.2f}'.format(
      average_precision))
# Out:
# Average precision-recall score: 0.36

# %%
#plotting results as ROC
fig_rf = plot_result_roc(result_tb_rf,'ROC Curve Test')
fig_rf.savefig('ml_analysis/sb_analysis/clr_figures/rf_sbTB25_test_roc.pdf',bbox_inches='tight')

acc_score = metrics.accuracy_score(y_test_tb, tb_rf.predict(x_test_tb))

print('Accuracy score: {0:0.2f}'.format(
      acc_score))
# Out:
# Accuracy score: 0.75

# %% [markdown]
# ## Exporting Feature Importance
# Creating table of feature ID w/ feature importance for Alex to look at molecular networking

# %%
feat_info = pd.read_csv('classified-feature-table-data.tsv',sep='\t')
feat_info.head(3)
# Out:
#                                  id  #featureID                csi_smiles  \
# 0  056d022e7adbe4ef6653efa05d5b8112         667  CCCCCCC=CCCCCCCCC(=O)OCC
# 1  735cc5e83b0891f3f3f7187f8ee70423         946        CC(C)CC(=NCCCCCN)O
# 2  3602250da02502454e038abb20d0bb7e        1179                   missing
#
#   ms2_smiles ms2_library_match  parent_mass  retention_time  table_number  \
# 0    missing           missing     283.2632          6.1332             1
# 1    missing           missing     187.1805          0.9041             1
# 2    missing           missing     284.2949          4.5907             1
#
#                      smiles structure_source            kingdom  \
# 0  CCCCCCC=CCCCCCCCC(=O)OCC      CSIFingerID  Organic compounds
# 1        CC(C)CC(=NCCCCCN)O      CSIFingerID       unclassified
# 2                   missing          missing       unclassified
#
#                         superclass         class           subclass  \
# 0  Lipids and lipid-like molecules   Fatty Acyls  Fatty acid esters
# 1                     unclassified  unclassified       unclassified
# 2                     unclassified  unclassified       unclassified
#
#        direct_parent
# 0  Fatty acid esters
# 1       unclassified
# 2       unclassified

# %%
tb_imp = pd.Series(tb_rf.feature_importances_).to_frame()
tb_imp.columns = ['feat importance']

# %%
#going through table to find featureID
id_col = []
hash_col = []
king_col = []
supclass_col = []
class_col = []
subclass_col = []
dp_col = []
sb_col = []
for idx in tb_imp.index:
    hash_id = sb_tb25_table.columns[idx]
    sb_diff = sb_diff_AF[sb_diff_AF.featureid==hash_id]['ATTRIBUTE_adv_fibrosis[T.1]'].iloc[0]
    sb_col.append(sb_diff)
    hash_col.append(hash_id)
    fbmn_id = feat_info[feat_info.id==hash_id]['#featureID'].iloc[0]
    taxa = feat_info.loc[idx][['kingdom','superclass','class','subclass','direct_parent']]
    king_col.append(taxa[0])#+','+taxa[1]+','+taxa[2]+','+taxa[3]+','+taxa[4]
    supclass_col.append(taxa[1])
    class_col.append(taxa[2])
    subclass_col.append(taxa[3])
    dp_col.append(taxa[4])
    id_col.append(fbmn_id)

# %%
tb_imp['hashedID'] = hash_col
tb_imp['featueID'] = id_col
tb_imp['ATTRIBUTE_adv_fibrosis[T.1]'] = sb_col
tb_imp['kingdom'] = king_col
tb_imp['superclass'] = supclass_col
tb_imp['class'] = class_col 
tb_imp['subclass'] = subclass_col
tb_imp['direct_parent'] = dp_col
tb_imp.head()
# Out:
#    feat importance                          hashedID  featueID  \
# 0         0.030164  fb758530086adf438d5ebe8f83847f2d      1022
# 1         0.016402  0ba75f593218ef056eefaeab285ae839      1017
# 2         0.037851  cdf8d23687cfc324485e2bd3e0094ff2      1019
# 3         0.020628  d2ef3361261cc1d835ad59394bfe161c      1018
# 4         0.045941  4deeef4aa3231abf469afec860b7b1ea       480
#
#                                             taxonomy            kingdom  \
# 0  Organic compounds,Lipids and lipid-like molecu...  Organic compounds
# 1  unclassified,unclassified,unclassified,unclass...       unclassified
# 2  unclassified,unclassified,unclassified,unclass...       unclassified
# 3  unclassified,unclassified,unclassified,unclass...       unclassified
# 4  Organic compounds,Organic acids and derivative...  Organic compounds
#
#                         superclass                             class  \
# 0  Lipids and lipid-like molecules                       Fatty Acyls
# 1                     unclassified                      unclassified
# 2                     unclassified                      unclassified
# 3                     unclassified                      unclassified
# 4    Organic acids and derivatives  Carboxylic acids and derivatives
#
#                                subclass                  direct_parent  \
# 0                     Fatty acid esters              Fatty acid esters
# 1                          unclassified                   unclassified
# 2                          unclassified                   unclassified
# 3                          unclassified                   unclassified
# 4  Amino acids, peptides, and analogues  Phenylalanine and derivatives
#
#    ATTRIBUTE_adv_fibrosis[T.1]
# 0                     3.858487
# 1                     3.764050
# 2                     3.744521
# 3                     3.490579
# 4                     3.228154

# %%
tb_imp.to_csv('./fecal_ml_analysis/sb_topbot_featimp_taxa.tsv',sep='\t',index=False)

# %% [markdown]
# ## 3. Songbird Bottom 50 Feature Set

# %% [markdown]
# ### 3a. CV/Train Models on G1P+G3P Samples

# %%
#preparing training data for SB top 50
x_train_bot = sb_bot50_table.loc[train_table.index]
#label encoder
y_train_bot = []
for idx in train_table.index:
    if train_table.loc[idx,'adv_fibrosis'] == '1':
        y_train_bot.append(1)
    #even values that are 'missing' are still 0 for adv fibrosis
    else:
        y_train_bot.append(0)
y_train_bot = np.array(y_train_bot)
print(x_train_bot.shape)
print(len(y_train_bot))
# Out:
# (70, 50)
# 70

# %%
#plotting Precision-recall for Log Reg
fig_lr = cross_val_pr(0,x_train_bot,y_train_bot,'PR Curve Cross Validation')
fig_lr.savefig('ml_analysis/sb_analysis/clr_figures/lr_sbBOT50_cv_pr.pdf',bbox_inches='tight')

#plotting Precision-recall for Log Reg
fig_lr = cross_val_roc(0,x_train_bot,y_train_bot,'ROC Curve Cross Validation')
fig_lr.savefig('ml_analysis/sb_analysis/clr_figures/lr_sbBOT50_cv_roc.pdf',bbox_inches='tight')

# %%
#plotting CV for RF
fig_rf = cross_val_pr(1,x_train_bot,y_train_bot,'PR Curve Cross Validation')
fig_rf.savefig('ml_analysis/sb_analysis/clr_figures/rf_sbBOT50_cv_pr.pdf',bbox_inches='tight')

#plotting ROC for RF
fig_rf = cross_val_roc(1,x_train_bot,y_train_bot,'ROC Curve Cross Validation')
fig_rf.savefig('ml_analysis/sb_analysis/clr_figures/rf_sbBOT50_cv_roc.pdf',bbox_inches='tight')

# %%
#training Log Reg on training data
bot_lr = LogisticRegression(random_state=0,max_iter=200)
bot_lr.fit(x_train_bot, y_train_bot)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=200,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=0, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
#training RF on training data
bot_rf = RandomForestClassifier(500, oob_score=True, random_state=0)
bot_rf.fit(x_train_bot, y_train_bot)
bot_rf.oob_score_
# Out:
# 0.5428571428571428

# %% [markdown]
# ### 3b. Test Models on G3R Samples

# %%
# Preparing the test data for BAB and SB
x_test_bot = sb_bot50_table.loc[test_table.index]
y_test_bot = []
for idx in test_table.index:
    if test_table.loc[idx,'adv_fibrosis'] == '1':
        y_test_bot.append(1)
    elif test_table.loc[idx,'adv_fibrosis'] == '0':
        y_test_bot.append(0)
y_test_bot = np.array(y_test_bot)
print(len(x_test_bot))
print(len(y_test_bot))
# Out:
# 28
# 28

# %%
#testing the logistic regression base model
result_bot_lr = pd.DataFrame(bot_lr.predict_proba(x_test_bot))
result_bot_lr.columns = bot_lr.classes_
result_bot_lr['Y_TRUE'] = y_test_bot
result_bot_lr['CV'] = 0

# %%
#plotting results as Precision Recall curve
fig_lr = plot_result_pr(result_bot_lr,'PR Curve Test')
fig_lr.savefig('ml_analysis/sb_analysis/clr_figures/lr_sbBOT50_test_pr.pdf',bbox_inches='tight')

average_precision = metrics.average_precision_score(y_test_bot, bot_lr.predict(x_test_bot))

print('Average precision-recall score: {0:0.2f}'.format(
      average_precision))
# Out:
# Average precision-recall score: 0.26

# %%
#plotting results as ROC
fig_lr = plot_result_roc(result_bot_lr,'ROC Curve Test')
fig_lr.savefig('ml_analysis/sb_analysis/clr_figures/lr_sbBOT50_test_roc.pdf',bbox_inches='tight')

acc_score = metrics.accuracy_score(y_test_bot, bot_lr.predict(x_test_bot))

print('Accuracy score: {0:0.2f}'.format(
      acc_score))
# Out:
# Accuracy score: 0.57

# %%
#testing the logistic regression base model
result_bot_rf = pd.DataFrame(bot_rf.predict_proba(x_test_bot))
result_bot_rf.columns = bot_rf.classes_
result_bot_rf['Y_TRUE'] = y_test_bot
result_bot_rf['CV'] = 0

# %%
#plotting results as Precision Recall curve
fig_rf = plot_result_pr(result_bot_rf,'PR Curve Test')
fig_rf.savefig('ml_analysis/sb_analysis/clr_figures/rf_sbBOT50_test_pr.pdf',bbox_inches='tight')

average_precision = metrics.average_precision_score(y_test_bot, bot_rf.predict(x_test_bot))

print('Average precision-recall score: {0:0.2f}'.format(
      average_precision))
# Out:
# Average precision-recall score: 0.25

# %%
#plotting results as ROC
fig_rf = plot_result_roc(result_bot_rf,'RF: ROC Test')
fig_rf.savefig('ml_analysis/sb_analysis/clr_figures/rf_sbBOT50_test_roc.pdf',bbox_inches='tight')

acc_score = metrics.accuracy_score(y_test_bot, bot_rf.predict(x_test_bot))

print('Accuracy score: {0:0.2f}'.format(
      acc_score))
# Out:
# Accuracy score: 0.61

# %% [markdown]
# ## Export the list of Features

# %%
with open('./fecal_ml_analysis/sonbird_topbot.txt', 'w') as f:
    for item in sb_tb25_id:
        f.write("%s\n" % item)

# %% [markdown]
# ## 4. Adding BMI, Gender and Age to Feature Table
# In the previous study done on the microbiome, adding BMI, Gender and Age to the feature table gave solid accuracy improvments for the model. These features are already used in the clinical setting as a way to diagnos NAFLD through uninvasive means. From this analysis the best performing model was the Songbird Top25/Bot25 Model.

# %%
clin_feat = meta.loc[:,['ATTRIBUTE_BiologicalSex','ATTRIBUTE_bmi','ATTRIBUTE_age']]
clin_feat.rename(columns={"ATTRIBUTE_BiologicalSex": "gender", "ATTRIBUTE_bmi": "bmi","ATTRIBUTE_age":"age"},inplace=True)
clin_feat
# Out:
#                                gender          bmi   age
# sample_name
# CIR16-001_BE5_01_29885.mzXML   female  38.95012056  52.0
# CIR16-002_RC7_01_29715.mzXML   female  31.03390116  71.0
# CIR18-001_BD4_01_29873.mzXML   female  34.86434801  63.0
# CIR18-002_BC9_01_29855.mzXML   female  33.56161928  63.0
# CIR19-001_RB12_01_29707.mzXML  female  42.66915271  61.0
# ...                               ...          ...   ...
# TW-DZ-001_RA12_01_29694.mzXML  female         32.5  65.0
# TW-DZ-002_RB4_01_29699.mzXML   female         30.1  65.0
# TW-EE-001_RB3_01_29801.mzXML     male         24.4  21.0
# TW-EE-002_RB5_01_29700.mzXML     male         21.9  21.0
# TW-EH-002_RA7_01_29792.mzXML     male         27.1  56.0
#
# [206 rows x 3 columns]

# %% [markdown]
# ### 4a. Train Models on G1P+G3P Individuals

# %%
x_train_comb = pd.concat([sb_tb25_table.loc[train_table.index], clin_feat.loc[train_table.index]],axis=1)
x_train_comb.gender = pd.factorize(x_train_comb.gender)[0]
x_train_comb = x_train_comb[x_train_comb.bmi != 'Missing: Not collected']
print(x_train_comb.shape)
# Out:
# (79, 53)

# %% [markdown]
# **Had to remove one sample that was Missing BMI value**

# %%
y_train_comb = []
for idx in x_train_comb.index:
    if meta.loc[idx, 'ATTRIBUTE_adv_fibrosis'] == '1':
        y_train_comb.append(1)
    else:    
        y_train_comb.append(0)
y_train_comb = np.array(y_train_comb)
print(len(y_train_comb))
print(y_train_comb.sum())
# Out:
# 79
# 23

# %%
#Cross Validating the Log Reg
fig_lr = cross_val_pr(0,x_train_comb,y_train_comb,'PR Curve Cross Validation')
fig_lr.savefig('fecal_ml_analysis/figures/lr_sbTB25+meta_cv_pr.pdf',bbox_inches='tight')

fig_lr = cross_val_roc(0,x_train_comb,y_train_comb,'ROC Curve Cross Validation')
fig_lr.savefig('fecal_ml_analysis/figures/lr_sbTB25+meta_cv_roc.pdf',bbox_inches='tight')

# %%
#Cross Validating the RF
fig_rf = cross_val_pr(1,x_train_comb,y_train_comb,'PR Curve Cross Validation')
fig_rf.savefig('fecal_ml_analysis/figures/rf_sbTB25+meta_cv_pr.pdf',bbox_inches='tight')

fig_rf = cross_val_roc(1,x_train_comb,y_train_comb,'ROC Curve Cross Validation')
fig_rf.savefig('fecal_ml_analysis/figures/rf_sbTB25+meta_cv_roc.pdf',bbox_inches='tight')

# %%
#training Log Reg on training data
comb_lr = LogisticRegression(random_state=0,max_iter=350)
comb_lr.fit(x_train_comb, y_train_comb)
# Out:
# LogisticRegression(max_iter=350, random_state=0)

# %%
#training RF on training data
comb_rf = RandomForestClassifier(500, oob_score=True, random_state=0)
comb_rf.fit(x_train_comb, y_train_comb)
comb_rf.oob_score_
# Out:
# 0.810126582278481

# %% [markdown]
# ### 4b. Testing Models on G3R Samples

# %%
x_test_comb = pd.concat([sb_tb25_table.loc[test_table.index], clin_feat.loc[test_table.index]],axis=1)
x_test_comb.gender = pd.factorize(x_test_comb.gender)[0]
x_test_comb.shape
# Out:
# (32, 53)

# %%
# Preparing the test data
y_test_comb = []
for idx in x_test_comb.index:
    if meta.loc[idx,'ATTRIBUTE_adv_fibrosis'] == '1':
        y_test_comb.append(1)
    elif meta.loc[idx,'ATTRIBUTE_adv_fibrosis'] == '0':
        y_test_comb.append(0)
y_test_comb = np.array(y_test_comb)
print(len(y_test_comb))
# Out:
# 32

# %%
#testing log reg
result_comb_lr = pd.DataFrame(comb_lr.predict_proba(x_test_comb))
result_comb_lr.columns = comb_lr.classes_
result_comb_lr['Y_TRUE'] = y_test_comb
result_comb_lr['CV'] = 0

# %%
#showing Precision-recall results
fig_comb_lr = plot_result_pr(result_comb_lr,'PR Curve Test')
fig_comb_lr.savefig('fecal_ml_analysis/figures/lr_sbTB25+meta_test_pr.pdf',bbox_inches='tight')

average_precision = metrics.average_precision_score(y_test_comb, comb_lr.predict(x_test_comb))

print('Average precision-recall score: {0:0.2f}'.format(
      average_precision))
# Out:
# Average precision-recall score: 0.47

# %%
#showing accuracy/ROC results
fig_comb_lr = plot_result_roc(result_comb_lr,'ROC Curve Test')
fig_comb_lr.savefig('fecal_ml_analysis/figures/lr_sbTB25+meta_test_roc.pdf',bbox_inches='tight')

acc_score = metrics.accuracy_score(y_test_comb, comb_lr.predict(x_test_comb))

print('Accuracy score: {0:0.2f}'.format(
      acc_score))
# Out:
# Accuracy score: 0.78

# %%
#testing RF
result_comb_rf = pd.DataFrame(comb_rf.predict_proba(x_test_comb))
result_comb_rf.columns = comb_rf.classes_
result_comb_rf['Y_TRUE'] = y_test_comb
result_comb_rf['CV'] = 0

# %%
#showing Precision-recall results
fig_comb_rf = plot_result_pr(result_comb_rf,'PR Curve Test')
fig_comb_rf.savefig('fecal_ml_analysis/figures/rf_sbTB25+meta_test_pr.pdf',bbox_inches='tight')

average_precision = metrics.average_precision_score(y_test_comb, comb_rf.predict(x_test_comb))

print('Average precision-recall score: {0:0.2f}'.format(
    
      average_precision))
# Out:
# Average precision-recall score: 0.41

# %%
#showing accuracy/ROC results
fig_comb_rf = plot_result_roc(result_comb_rf,'ROC Curve Test')
fig_comb_rf.savefig('fecal_ml_analysis/figures/rf_sbTB25+meta_test_roc.pdf',bbox_inches='tight')

acc_score = metrics.accuracy_score(y_test_comb, comb_rf.predict(x_test_comb))

print('Accuracy score: {0:0.2f}'.format(
      acc_score))
# Out:
# Accuracy score: 0.75

# %% [markdown]
# ### Investigating Top25+Bot25 SB Features

# %%
sb_tb_feat = pd.read_csv('./fecal_ml_analysis/sonbird_topbot.txt',sep='\t',header=None)
sb_tb_feat.columns = ['id']
sb_tb_feat.head()
# Out:
#                                  id
# 0  fb758530086adf438d5ebe8f83847f2d
# 1  0ba75f593218ef056eefaeab285ae839
# 2  cdf8d23687cfc324485e2bd3e0094ff2
# 3  d2ef3361261cc1d835ad59394bfe161c
# 4  4deeef4aa3231abf469afec860b7b1ea

# %%
feat_info = pd.read_csv('./classified-feature-table-data.tsv',sep='\t')
feat_info.head()
# Out:
#                                  id  #featureID                csi_smiles  \
# 0  056d022e7adbe4ef6653efa05d5b8112         667  CCCCCCC=CCCCCCCCC(=O)OCC
# 1  735cc5e83b0891f3f3f7187f8ee70423         946        CC(C)CC(=NCCCCCN)O
# 2  3602250da02502454e038abb20d0bb7e        1179                   missing
# 3  d66ab13eb87fd0f6688ef1f5332cf25f         330         C1=CC=C(C=C1)C=CO
# 4  3a2a812b26a0df79b008f0ca30844218         122  C1=CC=C(C=C1)CC(C(=O)O)N
#
#   ms2_smiles ms2_library_match  parent_mass  retention_time  table_number  \
# 0    missing           missing     283.2632          6.1332             1
# 1    missing           missing     187.1805          0.9041             1
# 2    missing           missing     284.2949          4.5907             1
# 3    missing           missing     121.0640          1.6710             1
# 4    missing     Phenylalanine     166.0873          9.8312             1
#
#                      smiles structure_source            kingdom  \
# 0  CCCCCCC=CCCCCCCCC(=O)OCC      CSIFingerID  Organic compounds
# 1        CC(C)CC(=NCCCCCN)O      CSIFingerID       unclassified
# 2                   missing          missing       unclassified
# 3         C1=CC=C(C=C1)C=CO      CSIFingerID       unclassified
# 4  C1=CC=C(C=C1)CC(C(=O)O)N      CSIFingerID  Organic compounds
#
#                         superclass                             class  \
# 0  Lipids and lipid-like molecules                       Fatty Acyls
# 1                     unclassified                      unclassified
# 2                     unclassified                      unclassified
# 3                     unclassified                      unclassified
# 4    Organic acids and derivatives  Carboxylic acids and derivatives
#
#                                subclass                  direct_parent
# 0                     Fatty acid esters              Fatty acid esters
# 1                          unclassified                   unclassified
# 2                          unclassified                   unclassified
# 3                          unclassified                   unclassified
# 4  Amino acids, peptides, and analogues  Phenylalanine and derivatives

# %%
filt_feat_info = feat_info[feat_info.id.isin(sb_tb_feat.id)]
filt_feat_info
# Out:
#                                    id  #featureID  \
# 12   f174e3629110b9080182a65e91cd4735         643
# 60   9d3664902e2848338dd710fded7d8434          42
# 114  87fe8c126302167c9c2dd616d938702c          44
# 124  87b2ee3ab5930cf0663d663ff1b3c524          14
# 138  724dece7c572c5e0d5aabf61684111fb          95
# 189  35841b633732fc98d6bc6a0056cdb239         491
# 195  11aa27badd53e050c47d272982cb6175         578
# 203  4508ce20c9b99a6e1c24fd3afdbc1e2f        1028
# 212  d2ef3361261cc1d835ad59394bfe161c        1018
# 213  fb758530086adf438d5ebe8f83847f2d        1022
# 246  4e5e19253c5d28ec21b401600be290ee        1068
# 267  c1aa71656d6e2ef3535930d0b09ca012         662
# 279  209e577b424fd09b8808ccadd4edfce6         277
# 301  f16fb9a4556296869e4f5e582a914dd2         164
# 302  330ecd6db6cc2c9b2017df5c06fb44f5         303
# 347  ed3a44853319e7c7bc2d91254f3242c2         495
# 350  f79e87a88230b8782266ce098425c4ce         734
# 357  b1641320e489f96bb9ddd6b08a7e574e         828
# 364  4deeef4aa3231abf469afec860b7b1ea         480
# 375  f3c9367e79341d7de4456c32b588b86f        1109
# 399  5d6c8094421e22fa24e09de3169f49b4         932
# 402  7a911427193391d0b2c384e18b713ad4         760
# 409  c0095c69fee5c767903814b366fcb860        1021
# 410  28a02f8e5fcae1d3b8d41678bf1276fd         410
# 419  db77705855bc4611e9c4fedca4b4f926        1025
# 455  832c0802efe61204586cbbefee574d43         589
# 471  0ba75f593218ef056eefaeab285ae839        1017
# 481  0c959ee3a5a474df1114c327dd8cdcac         478
# 494  5d2c67819b4dd934f18321dcdc75cf85         757
# 549  d1bce1e9a737c1904962ad8fa54cb922         382
# 550  0366e39a2c8c5aeaa60e42839a8b33e9         476
# 561  901b6e2bf2d45cfa9b38a99784cd0459         931
# 588  31b4a92e41933b13e3182509ebcd71e6         474
# 632  74ef5447fa19d579f9d3bed4c6654474         372
# 634  039ff7a0517b5399a9c2730881803a67         622
# 699  aa6b4c72ce8f060cfadb4f3aa04aae7e        1304
# 748  3d7f155024af16ecbe4c9baefdd571be         157
# 749  f2f3dfa3c15062c6cc6fdda001f9ab52         704
# 760  c077835e4654dfb74cab779b94de9bef        1115
# 763  8906c43cbd5e72d65ed9e7aacd1c2321         361
# 766  96b403a72b908f4441f02ac6993f79d4         377
# 774  b591a5b10d81884ab46dca87ee7c4e5f        1135
# 794  09fab3229ecdaa58a2d4c295ce4727fb         214
# 837  7fec8b00615260af68f5d4b7314c4d04         437
# 842  7974a034303060583acc9dbfc74de3f2         301
# 881  b9d0d8cbd02d4156cefd38457c7f06e3         681
# 917  cdf8d23687cfc324485e2bd3e0094ff2        1019
# 942  b6726454659b6df5b665d54fe00a7d07        1009
# 964  d5cc60bea702e172dfc486ff90b2d833        1253
# 965  35def52a34fbd75d08ef99a87b5251da         568
#
#                                             csi_smiles  \
# 12                            CCCCCC=CCC=CCCCCCCCCC#CO
# 60   CCCCC1=NC(=C(CO)N1CC2=CC=C(C=C2)C3=C(C=CC=C3)C...
# 114  CC(CCC1=NC(=C(CO)N1CC2=CC=C(C=C2)C3=C(C=CC=C3)...
# 124                                            missing
# 138     CC(CCC(=O)O)C1CCC2C3CCC4=CC(=O)CCC4(C)C3CCC12C
# 189                      [CH]CCCCCC(CCCCCCCCCCC(=O)O)O
# 195                              CC1=CN(C)C(=O)C(=N1)C
# 203                                    CC=CC=CCN=C(C)O
# 212                  C(COCCOCCOCCOCCOCCOCCOCCOCCOCCO)O
# 213   CC(C)CC(C(=NC(C)C)O)N=C(C(CO)N=C(C1CCC(=N1)O)O)O
# 246                               CC1(CCC1)CC(C(=O)O)N
# 267                      CC=CCCC=CCC=CCC=CCCCCCCC(=O)O
# 279           CC(C)CC(C(=NC(CC1=CC=C(C=C1)O)C(=O)O)O)N
# 301  CCCCCC(=NC(C(C)C)C(=NC(CCC(=O)C)C(=NC(CC(C)C)C...
# 302  CC(CCC(=O)O)C1CCC2C3C=CC4=CC(=O)CCC4(C)C3CC(C1...
# 347  CC(C)C(=O)OCC1(CC23CC1CCC3C4(C)CCCC(COC(=O)C)(...
# 350        CC(C)CC(C(=O)O)N=C(C(C)N=C(CN=C(C(C)N)O)O)O
# 357                     C1=CC2=C(C=C1)NC(=CC2=O)C(=O)O
# 364  CCCCCCCCC=CCCCCCCCC(=O)OCC(COP(=O)([O-])OCC[N+...
# 375                           CCCCC(CCCCCCCCCO)OC(=O)C
# 399         CCCCCCCCC1=CC=NC(=C1)C2=NC=CC(=C2)CCCCCCCC
# 402                   CCCCCCCCCCCC(=NCCCOC(=O)CN(C)C)O
# 409  CC(C)CC(C(=NC(CO)C(=O)N1CCCC1C(=NC(C(C)C)C(=O)...
# 410                                CCCCCCC=CCCCCCCC#CO
# 419                                            missing
# 455                          C=CCCCCCC=CCCCCCCCCC(=N)O
# 471               C(COCCOCCOCCOCCOCCOCCOCCOCCOCCOCCO)O
# 481                    CCCCCCCC=CCCCCCCCCC(=O)OCC(CO)O
# 494                   C(CCCCCCC1=CC=CC=C1)CCCCCCC(=O)O
# 549                             C(CCNC1CC1)CC(C(=O)O)N
# 550                                            missing
# 561              CCCCCCCCC1=C(CCCCCCCC)N=C2C=CC=CC2=N1
# 588   CCCCCCC(=NC(CCCCC)C(=NCCCC(=O)ON1C(=O)CCC1=O)O)O
# 632                     CC(C)CC(C(=NC(C(C)C)C(=O)O)O)N
# 634           CCCCCCCCCCCCCCCCCCCCC1=CC=CC(=C1C(=O)O)O
# 699                             CCCCCCCCCCCC=CCC=CCC=O
# 748       CN(C)C1=NC(=NC(=N1)N(C)C)N(CC(=NN)O)N=C(CN)O
# 749                       CCCCCCCCCCCCCCCC=CC(C(CO)N)O
# 760                        CCCCCC(CCC=CCCCCCCCC(=O)O)O
# 763         CC(C1=C(C)N(CC2=CC=CC(=C2)OC)N=C1C)C(=O)OC
# 766                                CC(=NCCCCCN=C(C)O)O
# 774                           CCCCCCCCCC=CCCCCCCC(=N)O
# 794                    CCCCCCCCN(CCCCCCCC)CC1=CC=CC=C1
# 837                                    C=CCOCCOCC(=O)O
# 842                           CCCCCCCCC=CCCCCCCCC(=O)O
# 881                              CCCCC(CCCO)(CCCO)CCCO
# 917   CC(=NCCCC(CC(=NC(CCCN=C(C)O)CC(=O)OC)O)N=C(C)O)O
# 942  CC(C(=O)N1CCC(CC1)C(=O)N2CCOCC2)N=C(CCCCCCCCC(...
# 964           CC(C)CC(C(=O)O)N=C(C(CC1=CC=C(C=C1)O)N)O
# 965  CCCCCC=CCC=CCCCCCCCC(=O)OC(CCCCCC)CC=CCCCCCCCC...
#
#                                             ms2_smiles  \
# 12               CC(/CCC1C(=C)CCC2C(C)(C)CCCC12C)=C/CO
# 60   CCCCC1=NC(Cl)=C(CO)N1Cc1ccc(-c2ccccc2C2=NNN=N2...
# 114                                            missing
# 124                                            missing
# 138  C[C@@H]([C@H]1CC[C@]2([H])[C@]1(C)CC[C@@]3([H]...
# 189                                            missing
# 195                                            missing
# 203                                            missing
# 212                                            missing
# 213                                            missing
# 246                                            missing
# 267                                            missing
# 279                                            missing
# 301                                            missing
# 302                                            missing
# 347                                            missing
# 350                                            missing
# 357                                            missing
# 364                                            missing
# 375                                            missing
# 399                                            missing
# 402           CCCCCCCCCCCC(=O)NCCC[N+](C)(C)CC(=O)[O-]
# 409                                            missing
# 410                                            missing
# 419                                            missing
# 455                                            missing
# 471                                            missing
# 481                                            missing
# 494                                            missing
# 549                                            missing
# 550                                            missing
# 561                                            missing
# 588                                            missing
# 632                                            missing
# 634                                            missing
# 699                                            missing
# 748                                            missing
# 749                                            missing
# 760                                            missing
# 763                                            missing
# 766                                            missing
# 774                                            missing
# 794                                            missing
# 837                                            missing
# 842                                            missing
# 881                                            missing
# 917                                            missing
# 942                                            missing
# 964                                            missing
# 965                                            missing
#
#                                      ms2_library_match  parent_mass  \
# 12   NCGC00385919-01_C20H34O_2-Penten-1-ol, 5-[(1S,...     291.2679
# 60   MassbankEU:SM818901 Losartan|[2-butyl-5-chloro...     423.1691
# 114                                            missing     439.1643
# 124                                            missing     431.3531
# 138  (R)-4-((8S,9S,10R,13R,14S,17R)-10,13-dimethyl-...     373.2738
# 189                                            missing     299.2579
# 195                                            missing     139.0856
# 203                                            missing     140.1063
# 212  Spectral Match to Decaethylene glycol from NIST14     459.2799
# 213                                            missing     393.2100
# 246                                            missing     180.0997
# 267                                            missing     305.2469
# 279                                            missing     295.1649
# 301        Spectral Match to Lyso-PC(16:0) from NIST14     496.3398
# 302                                            missing     387.2529
# 347                                            missing     481.2800
# 350                                            missing     331.1968
# 357                                            missing     190.0493
# 364  Spectral Match to 1-(9Z-Octadecenoyl)-sn-glyce...     522.3555
# 375                                            missing     295.2244
# 399                                            missing     381.3267
# 402                              CocamidopropylBetaine     343.2956
# 409                                            missing     437.2357
# 410   Spectral Match to Palmitelaidic acid from NIST14     237.2210
# 419                                            missing     520.3329
# 455                                            missing     280.2633
# 471  Spectral Match to Undecaethylene glycol from N...     503.3063
# 481          Spectral Match to Monoelaidin from NIST14     357.2997
# 494                                            missing     327.2291
# 549                                            missing     209.1259
# 550                                            missing     520.3398
# 561                                            missing     355.3107
# 588                                            missing     440.2773
# 632                                            missing     231.1695
# 634                                            missing     419.3519
# 699                                            missing     265.2520
# 748                                            missing     349.1822
# 749                                            missing     328.3211
# 760                                            missing     299.2582
# 763                                            missing     303.1710
# 766                                            missing     187.1436
# 774                                            missing     282.2793
# 794                                            missing     332.3311
# 837                                            missing     183.0623
# 842                                            missing     283.2631
# 881                                            missing     247.2266
# 917  Spectral Match to Nonaethylene glycol from NIST14     415.2535
# 942                                            missing     468.3065
# 964                                            missing     295.1650
# 965                                            missing     561.4878
#
#      retention_time  table_number  \
# 12           5.1520             1
# 60           3.2091             1
# 114          3.0034             1
# 124          8.8194             1
# 138          4.8976             1
# 189          5.5963             1
# 195          1.3086             1
# 203          2.6116             1
# 212          2.4980             1
# 213          2.4014             1
# 246          1.0146             1
# 267          6.4842             1
# 279          0.9618             1
# 301          4.8149             1
# 302          3.6089             1
# 347          2.8954             1
# 350          0.8173             1
# 357          1.2936             1
# 364          4.9919             1
# 375          4.6781             1
# 399          8.6291             1
# 402          3.4877             1
# 409          2.4527             1
# 410          4.6807             1
# 419          2.5335             1
# 455          5.9531             1
# 471          2.5330             1
# 481          6.5002             1
# 494          6.5165             1
# 549          0.7765             1
# 550          4.5764             1
# 561          8.5498             1
# 588          4.4119             1
# 632          2.4699             1
# 634          8.6017             1
# 699          6.5269             1
# 748          2.3067             1
# 749          4.7750             1
# 760          5.0065             1
# 763          3.2374             1
# 766          0.7825             1
# 774          4.8693             1
# 794          5.4450             1
# 837          1.6336             1
# 842          5.3883             1
# 881          6.0653             1
# 917          2.4577             1
# 942          2.8020             1
# 964          2.1364             1
# 965          6.5199             1
#
#                                                 smiles structure_source  \
# 12               CC(/CCC1C(=C)CCC2C(C)(C)CCCC12C)=C/CO              MS2
# 60   CCCCC1=NC(Cl)=C(CO)N1Cc1ccc(-c2ccccc2C2=NNN=N2...              MS2
# 114  CC(CCC1=NC(=C(CO)N1CC2=CC=C(C=C2)C3=C(C=CC=C3)...      CSIFingerID
# 124                                            missing          missing
# 138  C[C@@H]([C@H]1CC[C@]2([H])[C@]1(C)CC[C@@]3([H]...              MS2
# 189                      [CH]CCCCCC(CCCCCCCCCCC(=O)O)O      CSIFingerID
# 195                              CC1=CN(C)C(=O)C(=N1)C      CSIFingerID
# 203                                    CC=CC=CCN=C(C)O      CSIFingerID
# 212                  C(COCCOCCOCCOCCOCCOCCOCCOCCOCCO)O      CSIFingerID
# 213   CC(C)CC(C(=NC(C)C)O)N=C(C(CO)N=C(C1CCC(=N1)O)O)O      CSIFingerID
# 246                               CC1(CCC1)CC(C(=O)O)N      CSIFingerID
# 267                      CC=CCCC=CCC=CCC=CCCCCCCC(=O)O      CSIFingerID
# 279           CC(C)CC(C(=NC(CC1=CC=C(C=C1)O)C(=O)O)O)N      CSIFingerID
# 301  CCCCCC(=NC(C(C)C)C(=NC(CCC(=O)C)C(=NC(CC(C)C)C...      CSIFingerID
# 302  CC(CCC(=O)O)C1CCC2C3C=CC4=CC(=O)CCC4(C)C3CC(C1...      CSIFingerID
# 347  CC(C)C(=O)OCC1(CC23CC1CCC3C4(C)CCCC(COC(=O)C)(...      CSIFingerID
# 350        CC(C)CC(C(=O)O)N=C(C(C)N=C(CN=C(C(C)N)O)O)O      CSIFingerID
# 357                     C1=CC2=C(C=C1)NC(=CC2=O)C(=O)O      CSIFingerID
# 364  CCCCCCCCC=CCCCCCCCC(=O)OCC(COP(=O)([O-])OCC[N+...      CSIFingerID
# 375                           CCCCC(CCCCCCCCCO)OC(=O)C      CSIFingerID
# 399         CCCCCCCCC1=CC=NC(=C1)C2=NC=CC(=C2)CCCCCCCC      CSIFingerID
# 402           CCCCCCCCCCCC(=O)NCCC[N+](C)(C)CC(=O)[O-]              MS2
# 409  CC(C)CC(C(=NC(CO)C(=O)N1CCCC1C(=NC(C(C)C)C(=O)...      CSIFingerID
# 410                                CCCCCCC=CCCCCCCC#CO      CSIFingerID
# 419                                            missing          missing
# 455                          C=CCCCCCC=CCCCCCCCCC(=N)O      CSIFingerID
# 471               C(COCCOCCOCCOCCOCCOCCOCCOCCOCCOCCO)O      CSIFingerID
# 481                    CCCCCCCC=CCCCCCCCCC(=O)OCC(CO)O      CSIFingerID
# 494                   C(CCCCCCC1=CC=CC=C1)CCCCCCC(=O)O      CSIFingerID
# 549                             C(CCNC1CC1)CC(C(=O)O)N      CSIFingerID
# 550                                            missing          missing
# 561              CCCCCCCCC1=C(CCCCCCCC)N=C2C=CC=CC2=N1      CSIFingerID
# 588   CCCCCCC(=NC(CCCCC)C(=NCCCC(=O)ON1C(=O)CCC1=O)O)O      CSIFingerID
# 632                     CC(C)CC(C(=NC(C(C)C)C(=O)O)O)N      CSIFingerID
# 634           CCCCCCCCCCCCCCCCCCCCC1=CC=CC(=C1C(=O)O)O      CSIFingerID
# 699                             CCCCCCCCCCCC=CCC=CCC=O      CSIFingerID
# 748       CN(C)C1=NC(=NC(=N1)N(C)C)N(CC(=NN)O)N=C(CN)O      CSIFingerID
# 749                       CCCCCCCCCCCCCCCC=CC(C(CO)N)O      CSIFingerID
# 760                        CCCCCC(CCC=CCCCCCCCC(=O)O)O      CSIFingerID
# 763         CC(C1=C(C)N(CC2=CC=CC(=C2)OC)N=C1C)C(=O)OC      CSIFingerID
# 766                                CC(=NCCCCCN=C(C)O)O      CSIFingerID
# 774                           CCCCCCCCCC=CCCCCCCC(=N)O      CSIFingerID
# 794                    CCCCCCCCN(CCCCCCCC)CC1=CC=CC=C1      CSIFingerID
# 837                                    C=CCOCCOCC(=O)O      CSIFingerID
# 842                           CCCCCCCCC=CCCCCCCCC(=O)O      CSIFingerID
# 881                              CCCCC(CCCO)(CCCO)CCCO      CSIFingerID
# 917   CC(=NCCCC(CC(=NC(CCCN=C(C)O)CC(=O)OC)O)N=C(C)O)O      CSIFingerID
# 942  CC(C(=O)N1CCC(CC1)C(=O)N2CCOCC2)N=C(CCCCCCCCC(...      CSIFingerID
# 964           CC(C)CC(C(=O)O)N=C(C(CC1=CC=C(C=C1)O)N)O      CSIFingerID
# 965  CCCCCC=CCC=CCCCCCCCC(=O)OC(CCCCCC)CC=CCCCCCCCC...      CSIFingerID
#
#                kingdom                       superclass  \
# 12   Organic compounds  Lipids and lipid-like molecules
# 60   Organic compounds                       Benzenoids
# 114  Organic compounds                       Benzenoids
# 124       unclassified                     unclassified
# 138  Organic compounds  Lipids and lipid-like molecules
# 189  Organic compounds  Lipids and lipid-like molecules
# 195  Organic compounds     Organoheterocyclic compounds
# 203       unclassified                     unclassified
# 212  Organic compounds         Organic oxygen compounds
# 213       unclassified                     unclassified
# 246       unclassified                     unclassified
# 267       unclassified                     unclassified
# 279  Organic compounds    Organic acids and derivatives
# 301       unclassified                     unclassified
# 302  Organic compounds  Lipids and lipid-like molecules
# 347       unclassified                     unclassified
# 350       unclassified                     unclassified
# 357  Organic compounds     Organoheterocyclic compounds
# 364  Organic compounds  Lipids and lipid-like molecules
# 375       unclassified                     unclassified
# 399       unclassified                     unclassified
# 402  Organic compounds    Organic acids and derivatives
# 409       unclassified                     unclassified
# 410  Organic compounds         Organic oxygen compounds
# 419       unclassified                     unclassified
# 455  Organic compounds  Lipids and lipid-like molecules
# 471  Organic compounds         Organic oxygen compounds
# 481       unclassified                     unclassified
# 494  Organic compounds  Lipids and lipid-like molecules
# 549       unclassified                     unclassified
# 550       unclassified                     unclassified
# 561       unclassified                     unclassified
# 588       unclassified                     unclassified
# 632  Organic compounds    Organic acids and derivatives
# 634  Organic compounds                       Benzenoids
# 699  Organic compounds  Lipids and lipid-like molecules
# 748       unclassified                     unclassified
# 749  Organic compounds       Organic nitrogen compounds
# 760  Organic compounds  Lipids and lipid-like molecules
# 763       unclassified                     unclassified
# 766  Organic compounds    Organic acids and derivatives
# 774  Organic compounds  Lipids and lipid-like molecules
# 794  Organic compounds                       Benzenoids
# 837       unclassified                     unclassified
# 842  Organic compounds  Lipids and lipid-like molecules
# 881       unclassified                     unclassified
# 917  Organic compounds    Organic acids and derivatives
# 942       unclassified                     unclassified
# 964  Organic compounds    Organic acids and derivatives
# 965       unclassified                     unclassified
#
#                                    class  \
# 12                         Prenol lipids
# 60   Benzene and substituted derivatives
# 114  Benzene and substituted derivatives
# 124                         unclassified
# 138     Steroids and steroid derivatives
# 189                          Fatty Acyls
# 195                             Diazines
# 203                         unclassified
# 212               Organooxygen compounds
# 213                         unclassified
# 246                         unclassified
# 267                         unclassified
# 279     Carboxylic acids and derivatives
# 301                         unclassified
# 302     Steroids and steroid derivatives
# 347                         unclassified
# 350                         unclassified
# 357           Quinolines and derivatives
# 364                 Glycerophospholipids
# 375                         unclassified
# 399                         unclassified
# 402     Carboxylic acids and derivatives
# 409                         unclassified
# 410               Organooxygen compounds
# 419                         unclassified
# 455                          Fatty Acyls
# 471               Organooxygen compounds
# 481                         unclassified
# 494                          Fatty Acyls
# 549                         unclassified
# 550                         unclassified
# 561                         unclassified
# 588                         unclassified
# 632     Carboxylic acids and derivatives
# 634  Benzene and substituted derivatives
# 699                          Fatty Acyls
# 748                         unclassified
# 749             Organonitrogen compounds
# 760                          Fatty Acyls
# 763                         unclassified
# 766     Carboxylic acids and derivatives
# 774                          Fatty Acyls
# 794  Benzene and substituted derivatives
# 837                         unclassified
# 842                          Fatty Acyls
# 881                         unclassified
# 917     Carboxylic acids and derivatives
# 942                         unclassified
# 964     Carboxylic acids and derivatives
# 965                         unclassified
#
#                                  subclass  \
# 12                           Diterpenoids
# 60              Biphenyls and derivatives
# 114             Biphenyls and derivatives
# 124                          unclassified
# 138  Bile acids, alcohols and derivatives
# 189            Fatty acids and conjugates
# 195                             Pyrazines
# 203                          unclassified
# 212                                Ethers
# 213                          unclassified
# 246                          unclassified
# 267                          unclassified
# 279  Amino acids, peptides, and analogues
# 301                          unclassified
# 302  Bile acids, alcohols and derivatives
# 347                          unclassified
# 350                          unclassified
# 357            Quinoline carboxylic acids
# 364                Glycerophosphocholines
# 375                          unclassified
# 399                          unclassified
# 402  Amino acids, peptides, and analogues
# 409                          unclassified
# 410                                 Ynols
# 419                          unclassified
# 455                          Fatty amides
# 471                                Ethers
# 481                          unclassified
# 494            Fatty acids and conjugates
# 549                          unclassified
# 550                          unclassified
# 561                          unclassified
# 588                          unclassified
# 632  Amino acids, peptides, and analogues
# 634         Benzoic acids and derivatives
# 699                       Fatty aldehydes
# 748                          unclassified
# 749                                Amines
# 760            Fatty acids and conjugates
# 763                          unclassified
# 766           Carboxylic acid derivatives
# 774                          Fatty amides
# 794                    Phenylmethylamines
# 837                          unclassified
# 842            Fatty acids and conjugates
# 881                          unclassified
# 917  Amino acids, peptides, and analogues
# 942                          unclassified
# 964  Amino acids, peptides, and analogues
# 965                          unclassified
#
#                                         direct_parent
# 12                                       Diterpenoids
# 60                          Biphenyls and derivatives
# 114                         Biphenyls and derivatives
# 124                                      unclassified
# 138              Bile acids, alcohols and derivatives
# 189                            Long-chain fatty acids
# 195                                         Pyrazines
# 203                                      unclassified
# 212                              Polyethylene glycols
# 213                                      unclassified
# 246                                      unclassified
# 267                                      unclassified
# 279                                        Dipeptides
# 301                                      unclassified
# 302  Monohydroxy bile acids, alcohols and derivatives
# 347                                      unclassified
# 350                                      unclassified
# 357                        Quinoline carboxylic acids
# 364               1-acyl-sn-glycero-3-phosphocholines
# 375                                      unclassified
# 399                                      unclassified
# 402                                 Alpha amino acids
# 409                                      unclassified
# 410                                             Ynols
# 419                                      unclassified
# 455                                      Fatty amides
# 471                              Polyethylene glycols
# 481                                      unclassified
# 494                            Long-chain fatty acids
# 549                                      unclassified
# 550                                      unclassified
# 561                                      unclassified
# 588                                      unclassified
# 632                                        Dipeptides
# 634                                   Salicylic acids
# 699                                   Fatty aldehydes
# 748                                      unclassified
# 749                                 1,2-aminoalcohols
# 760                            Long-chain fatty acids
# 763                                      unclassified
# 766                                        Acetamides
# 774                                      Fatty amides
# 794                                Phenylmethylamines
# 837                                      unclassified
# 842                            Long-chain fatty acids
# 881                                      unclassified
# 917                  Beta amino acids and derivatives
# 942                                      unclassified
# 964                                        Dipeptides
# 965                                      unclassified
